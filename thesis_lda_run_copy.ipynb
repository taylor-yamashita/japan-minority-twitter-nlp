# %%
import import_ipynb
import thesis_preprocess
import thesis_lda
import gensim

# %% [markdown]
# ### Preprocess and Tokenize

# %%
# zainichi
txt_filename = "datasets_minority_groups/zainichi_2022.txt"
tokens_z22, tweets_z22 = thesis_lda.preprocess_tokenize_all_unique(txt_filename, "2022")
thesis_lda.save_to_csv(tokens_z22, "saved_tokens_unique/zainichi_2022.csv")
thesis_lda.save_to_csv(tweets_z22, "saved_tweets_unique/zainichi_2022.csv")

txt_filename = "datasets_minority_groups/zainichi_2015.txt"
tokens_z15, tweets_z15 = thesis_lda.preprocess_tokenize_all_unique(txt_filename, "2015")
thesis_lda.save_to_csv(tokens_z15, "saved_tokens_unique/zainichi_2015.csv")
thesis_lda.save_to_csv(tweets_z15, "saved_tweets_unique/zainichi_2015.csv")

# ainu
txt_filename = "datasets_minority_groups/ainu_2022.txt"
tokens_a22, tweets_a22 = thesis_lda.preprocess_tokenize_all_unique(txt_filename, "2022")
thesis_lda.save_to_csv(tokens_a22, "saved_tokens_unique/ainu_2022.csv")
thesis_lda.save_to_csv(tweets_a22, "saved_tweets_unique/ainu_2022.csv")

txt_filename = "datasets_minority_groups/ainu_2015.txt"
tokens_a15, tweets_a15 = thesis_lda.preprocess_tokenize_all_unique(txt_filename, "2022")
thesis_lda.save_to_csv(tokens_a15, "saved_tokens_unique/ainu_2015.csv")
thesis_lda.save_to_csv(tweets_a15, "saved_tweets_unique/ainu_2015.csv")

# okinawajin
txt_filename = "datasets_minority_groups/okinawajin_2022.txt"
tokens_o22, tweets_o22 = thesis_lda.preprocess_tokenize_all_unique(txt_filename, "2022")
thesis_lda.save_to_csv(tokens_o22, "saved_tokens_unique/okinawajin_2022.csv")
thesis_lda.save_to_csv(tweets_o22, "saved_tweets_unique/okinawajin_2022.csv")

txt_filename = "datasets_minority_groups/okinawajin_2015.txt"
tokens_o15, tweets_o15 = thesis_lda.preprocess_tokenize_all_unique(txt_filename, "2015")
thesis_lda.save_to_csv(tokens_o15, "saved_tokens_unique/okinawajin_2015.csv")
thesis_lda.save_to_csv(tweets_o15, "saved_tweets_unique/okinawajin_2015.csv")

# preprocess and tokenize
txt_filename = "datasets_minority_groups/ryukyujin_2022.txt"
tokens_rj22, tweets_rj22 = thesis_lda.preprocess_tokenize_all_unique(txt_filename, "2022")
thesis_lda.save_to_csv(tokens_rj22, "saved_tokens_unique/ryukyujin_2022.csv")
thesis_lda.save_to_csv(tweets_rj22, "saved_tweets_unique/ryukyujin_2022.csv")

txt_filename = "datasets_minority_groups/ryukyujin_2015.txt"
tokens_rj15, tweets_rj15 = thesis_lda.preprocess_tokenize_all_unique(txt_filename, "2015")
thesis_lda.save_to_csv(tokens_rj15, "saved_tokens_unique/ryukyujin_2015.csv")
thesis_lda.save_to_csv(tweets_rj15, "saved_tweets_unique/ryukyujin_2015.csv")

# haafu
txt_filename = "datasets_minority_groups/haafu_2015.txt"
tokens_h15, tweets_h15 = thesis_lda.preprocess_tokenize_all_unique(txt_filename, "2015")
thesis_lda.save_to_csv(tokens_h15, "saved_tokens_unique/haafu_2015.csv")
thesis_lda.save_to_csv(tweets_h15, "saved_tweets_unique/haafu_2015.csv")

txt_filename = "datasets_minority_groups/haafu_2022.txt"
tokens_h22, tweets_h22 = thesis_lda.preprocess_tokenize_all_unique(txt_filename, "2015")
thesis_lda.save_to_csv(tokens_h22, "saved_tokens_unique/haafu_2022.csv")
thesis_lda.save_to_csv(tweets_h22, "saved_tweets_unique/haafu_2022.csv")

# vietnamjin
txt_filename = "datasets_minority_groups/vietnamjin_2015.txt"
tokens_v15, tweets_v15 = thesis_lda.preprocess_tokenize_all_unique(txt_filename, "2015")
thesis_lda.save_to_csv(tokens_v15, "saved_tokens_unique/vietnamjin_2015.csv")
thesis_lda.save_to_csv(tweets_v15, "saved_tweets_unique/vietnamjin_2015.csv")

txt_filename = "datasets_minority_groups/vietnamjin_2022.txt"
tokens_v22, tweets_v22 = thesis_lda.preprocess_tokenize_all_unique(txt_filename, "2022")
thesis_lda.save_to_csv(tokens_v22, "saved_tokens_unique/vietnamjin_2022.csv")
thesis_lda.save_to_csv(tweets_v22, "saved_tweets_unique/vietnamjin_2022.csv")

# phiilippinejin
txt_filename = "datasets_minority_groups/philippinejin_2015.txt"
tokens_p15, tweets_p15 = thesis_lda.preprocess_tokenize_all_unique(txt_filename, "2015")
thesis_lda.save_to_csv(tokens_p15, "saved_tokens_unique/philippinejin_2015.csv")
thesis_lda.save_to_csv(tweets_p15, "saved_tweets_unique/philippinejin_2015.csv")

txt_filename = "datasets_minority_groups/philippinejin_2022.txt"
tokens_p22, tweets_p22 = thesis_lda.preprocess_tokenize_all_unique(txt_filename, "2022")
thesis_lda.save_to_csv(tokens_p22, "saved_tokens_unique/philippinejin_2022.csv")
thesis_lda.save_to_csv(tweets_p22, "saved_tweets_unique/philippinejin_2022.csv")
# Out:
# 31901
# 26011
# 23653
# 14545
# Retweet:  1768019931457823173
# Retweet:  1768019931457823173
# Retweet:  1768019931457823173
# Retweet:  1768019931457823173
# Retweet:  1768019931457823173
# Retweet:  1768019931457823173
# Retweet:  1768019931457823173
# Retweet:  1768019931457823173
# Retweet:  1768019931457823173
# Retweet:  1768019931457823173
# Retweet:  1768019931457823173
# Retweet:  1768019931457823173
# Retweet:  1768019931457823173
# Retweet:  1768019931457823173
# Retweet:  1768019931457823173
# Retweet:  1768019931457823173
# Retweet:  1768019931457823173
# Retweet:  1768019931457823173
# 177864
# 139506
# Retweet:  1772980992472703021
# Retweet:  1772980992472703021
# Retweet:  1772980992472703021
# Retweet:  1772980992472703021
# Retweet:  1772980992472703021
# Retweet:  1772980992472703021
# Retweet:  1772980992472703021
# Retweet:  1772980992472703021
# Retweet:  1772980992472703021
# Retweet:  1772980992472703021
# Retweet:  1772980992472703021
# ...

# %%
tokens_z15 = thesis_lda.load_from_csv("saved_tokens_unique/zainichi_2015.csv")
tokens_z22 = thesis_lda.load_from_csv("saved_tokens_unique/zainichi_2022.csv")
tweets_z15 = thesis_lda.load_from_csv("saved_tweets_unique/zainichi_2015.csv")
tweets_z22 = thesis_lda.load_from_csv("saved_tweets_unique/zainichi_2022.csv")

tokens_a15 = thesis_lda.load_from_csv("saved_tokens_unique/ainu_2015.csv")
tokens_a22 = thesis_lda.load_from_csv("saved_tokens_unique/ainu_2022.csv")
tweets_a15 = thesis_lda.load_from_csv("saved_tweets_unique/ainu_2015.csv")
tweets_a22 = thesis_lda.load_from_csv("saved_tweets_unique/ainu_2022.csv")

tokens_o15 = thesis_lda.load_from_csv("saved_tokens_unique/okinawajin_2015.csv")
tokens_o22 = thesis_lda.load_from_csv("saved_tokens_unique/okinawajin_2022.csv")
tweets_o15 = thesis_lda.load_from_csv("saved_tweets_unique/okinawajin_2015.csv")
tweets_o22 = thesis_lda.load_from_csv("saved_tweets_unique/okinawajin_2022.csv")

tokens_r15 = thesis_lda.load_from_csv("saved_tokens_unique/ryukyujin_2015.csv")
tokens_r22 = thesis_lda.load_from_csv("saved_tokens_unique/ryukyujin_2022.csv")
tweets_r15 = thesis_lda.load_from_csv("saved_tweets_unique/ryukyujin_2015.csv")
tweets_r22 = thesis_lda.load_from_csv("saved_tweets_unique/ryukyujin_2022.csv")

tokens_h15 = thesis_lda.load_from_csv("saved_tokens_unique/haafu_2015.csv")
tokens_h22 = thesis_lda.load_from_csv("saved_tokens_unique/haafu_2022.csv")
tweets_h15 = thesis_lda.load_from_csv("saved_tweets_unique/haafu_2015.csv")
tweets_h22 = thesis_lda.load_from_csv("saved_tweets_unique/haafu_2022.csv")

tokens_v15 = thesis_lda.load_from_csv("saved_tokens_unique/vietnamjin_2015.csv")
tokens_v22 = thesis_lda.load_from_csv("saved_tokens_unique/vietnamjin_2022.csv")
tweets_v15 = thesis_lda.load_from_csv("saved_tweets_unique/vietnamjin_2015.csv")
tweets_v22 = thesis_lda.load_from_csv("saved_tweets_unique/vietnamjin_2022.csv")

tokens_p15 = thesis_lda.load_from_csv("saved_tokens_unique/philippinejin_2015.csv")
tokens_p22 = thesis_lda.load_from_csv("saved_tokens_unique/philippinejin_2022.csv")
tweets_p15 = thesis_lda.load_from_csv("saved_tweets_unique/philippinejin_2015.csv")
tweets_p22 = thesis_lda.load_from_csv("saved_tweets_unique/philippinejin_2022.csv")

# %% [markdown]
# ### Determining Good # Topics

# %%
# zainichi korean
model_list, coherence_vals = thesis_lda.compute_coherence_values(tokens=tokens_z15, start=2, limit=40, step=6)
thesis_lda.show_coherence_vals(coherence_vals)
thesis_lda.plot_coherence_vals(coherence_vals)
# result: 20

model_list, coherence_vals = thesis_lda.compute_coherence_values(tokens=tokens_z22, start=2, limit=40, step=6)
thesis_lda.show_coherence_vals(coherence_vals)
thesis_lda.plot_coherence_vals(coherence_vals)
# result:
# Out:
# using autotuned alpha, starting with [0.5, 0.5]
# using symmetric eta at 0.5
# using serial LDA version on this node
# running online (multi-pass) LDA training, 2 topics, 10 passes over the supplied corpus of 14545 documents, updating model once every 6000 documents, evaluating perplexity every 14545 documents, iterating 50x with a convergence threshold of 0.001000
# PROGRESS: pass 0, at document #2000/14545
# optimized alpha [0.65877855, 0.713972]
# PROGRESS: pass 0, at document #4000/14545
# optimized alpha [0.9821856, 1.1364535]
# PROGRESS: pass 0, at document #6000/14545
# optimized alpha [1.544114, 1.8730574]
# merging changes from 6000 documents into a model of 14545 documents
# topic #0 (1.544): 0.020*"日本" + 0.011*"在日" + 0.010*"ヘイトスピチ" + 0.007*"てる" + 0.007*"韓国" + 0.007*"差別" + 0.007*"日本人" + 0.005*"デマ" + 0.005*"韓国人" + 0.005*"強制送還"
# ...

# %%
# ainu
model_list, coherence_vals = thesis_lda.compute_coherence_values(tokens=tokens_a15, start=2, limit=40, step=6)
thesis_lda.show_coherence_vals(coherence_vals)
thesis_lda.plot_coherence_vals(coherence_vals)
# result: 

model_list, coherence_vals = thesis_lda.compute_coherence_values(tokens=tokens_a22, start=2, limit=40, step=6)
thesis_lda.show_coherence_vals(coherence_vals)
thesis_lda.plot_coherence_vals(coherence_vals)
# result:

# %%
# okinawajin
model_list, coherence_vals = thesis_lda.compute_coherence_values(tokens=tokens_o15, start=2, limit=40, step=6)
thesis_lda.show_coherence_vals(coherence_vals)
thesis_lda.plot_coherence_vals(coherence_vals)
# result: 

model_list, coherence_vals = thesis_lda.compute_coherence_values(tokens=tokens_o22, start=2, limit=40, step=6)
thesis_lda.show_coherence_vals(coherence_vals)
thesis_lda.plot_coherence_vals(coherence_vals)
# result:

# %%
# ryukyujin
model_list, coherence_vals = thesis_lda.compute_coherence_values(tokens=tokens_r15, start=2, limit=40, step=6)
thesis_lda.show_coherence_vals(coherence_vals)
thesis_lda.plot_coherence_vals(coherence_vals)
# result: 

model_list, coherence_vals = thesis_lda.compute_coherence_values(tokens=tokens_r22, start=2, limit=40, step=6)
thesis_lda.show_coherence_vals(coherence_vals)
thesis_lda.plot_coherence_vals(coherence_vals)
# result:

# %%
# haafu
model_list, coherence_vals = thesis_lda.compute_coherence_values(tokens=tokens_h15, start=2, limit=40, step=6)
thesis_lda.show_coherence_vals(coherence_vals)
thesis_lda.plot_coherence_vals(coherence_vals)
# result: 

model_list, coherence_vals = thesis_lda.compute_coherence_values(tokens=tokens_h22, start=2, limit=40, step=6)
thesis_lda.show_coherence_vals(coherence_vals)
thesis_lda.plot_coherence_vals(coherence_vals)
# result:

# %%
# vietnamjin
model_list, coherence_vals = thesis_lda.compute_coherence_values(tokens=tokens_v15, start=2, limit=40, step=6)
thesis_lda.show_coherence_vals(coherence_vals)
thesis_lda.plot_coherence_vals(coherence_vals)
# result: 

model_list, coherence_vals = thesis_lda.compute_coherence_values(tokens=tokens_v22, start=2, limit=40, step=6)
thesis_lda.show_coherence_vals(coherence_vals)
thesis_lda.plot_coherence_vals(coherence_vals)
# result:

# %%
# philippinejin
model_list, coherence_vals = thesis_lda.compute_coherence_values(tokens=tokens_p15, start=2, limit=40, step=6)
thesis_lda.show_coherence_vals(coherence_vals)
thesis_lda.plot_coherence_vals(coherence_vals)
# result: 

model_list, coherence_vals = thesis_lda.compute_coherence_values(tokens=tokens_p22, start=2, limit=40, step=6)
thesis_lda.show_coherence_vals(coherence_vals)
thesis_lda.plot_coherence_vals(coherence_vals)
# result:

# %% [markdown]
# ### Running LDA

# %%
# zainichi korean
lda_z15, dict_z15, corpus_z15, train, test = thesis_lda.run_lda("zainichi_2015", tokens_z22, num_topics=8, dir="saved_lda_unique_models")
thesis_lda.analyze_train_test_results(lda_z15, train, test)
thesis_lda.analyze_overall_results(lda_z15, tokens_z22, dict_z15, corpus_z15)
thesis_lda.examine_topics_plain(lda_z15, dict_z15, num_topics=8)

lda_z22, dict_z22, corpus_z22, train, test = thesis_lda.run_lda("zainichi_2022", tokens_z22, num_topics=8, dir="saved_lda_unique_models")
thesis_lda.analyze_train_test_results(lda_z22, train, test)
thesis_lda.analyze_overall_results(lda_z22, tokens_z22, dict_z22, corpus_z22)
thesis_lda.examine_topics_plain(lda_z22, dict_z22, num_topics=8)

# %%
# ainu
lda_a22, dict_a22, corpus_a22, train, test = thesis_lda.run_lda("ainu_2022", tokens_a22, num_topics=8, dir="saved_lda_unique_models")
thesis_lda.analyze_train_test_results(lda_a22, train, test)
thesis_lda.analyze_overall_results(lda_a22, tokens_a22, dict_a22, corpus_a22)
thesis_lda.examine_topics_plain(lda_a22, dict_a22, num_topics=8)

lda_a15, dict_a15, corpus_a15, train, test = thesis_lda.run_lda("ainu_2015", tokens_a15, num_topics=14, dir="saved_lda_unique_models")
thesis_lda.analyze_train_test_results(lda_a15, train, test)
thesis_lda.analyze_overall_results(lda_a15, tokens_a15, dict_a15, corpus_a15)
thesis_lda.examine_topics_plain(lda_a15, dict_a15, num_topics=14)

# %%
# okinawajin
lda_o15, dict_o15, corpus_o15, train, test = thesis_lda.run_lda("okinawa_2015", tokens_o15, num_topics=8, dir="saved_lda_unique_models")
thesis_lda.analyze_train_test_results(lda_o15, train, test)
thesis_lda.analyze_overall_results(lda_o15, tokens_o15, dict_o15, corpus_o15)
thesis_lda.examine_topics_plain(lda_o15, dict_o15, num_topics=8)

lda_o22, dict_o22, corpus_o22, train, test = thesis_lda.run_lda("okinawa_2022", tokens_o22, num_topics=8, dir="saved_lda_unique_models")
thesis_lda.analyze_train_test_results(lda_o22, train, test)
thesis_lda.analyze_overall_results(lda_o22, tokens_o22, dict_o22, corpus_o22)
thesis_lda.examine_topics_plain(lda_o22, dict_o22, num_topics=8)

# %%
# ryukyujin
lda_rj15, dict_rj15, corpus_rj15, train, test = thesis_lda.run_lda("ryukyujin_2015", tokens_rj15, num_topics=8, dir="saved_lda_unique_models")
thesis_lda.analyze_train_test_results(lda_rj15, train, test)
thesis_lda.analyze_overall_results(lda_rj15, tokens_rj15, dict_rj15, corpus_rj15)
thesis_lda.examine_topics_plain(lda_rj15, dict_rj15, num_topics=8)

lda_rj22, dict_rj22, corpus_rj22, train, test = thesis_lda.run_lda("ryukyujin_2022", tokens_rj22, num_topics=8, dir="saved_lda_unique_models")
thesis_lda.analyze_train_test_results(lda_rj22, train, test)
thesis_lda.analyze_overall_results(lda_rj22, tokens_rj22, dict_rj22, corpus_rj22)
thesis_lda.examine_topics_plain(lda_rj22, dict_rj22, num_topics=8)

# %%
# haafu
lda_h15, dict_h15, corpus_h15, train, test = thesis_lda.run_lda("zainichi_2022", tokens_h15, num_topics=20, dir="saved_lda_unique_models")
thesis_lda.analyze_train_test_results(lda_h15, train, test)
thesis_lda.analyze_overall_results(lda_h15, tokens_h15, dict_h15, corpus_h15)
thesis_lda.examine_topics_plain(lda_h15, dict_h15, num_topics=20)

lda_h22, dict_h22, corpus_h22, train, test = thesis_lda.run_lda("haafu_2022", tokens_h22, num_topics=8, dir="saved_lda_unique_models")
thesis_lda.analyze_train_test_results(lda_h22, train, test)
thesis_lda.analyze_overall_results(lda_h22, tokens_h22, dict_h22, corpus_h22)
thesis_lda.examine_topics_plain(lda_h22, dict_h22, num_topics=8)

# %%
# vietnamjin
lda_v15, dict_v15, corpus_v15, train, test = thesis_lda.run_lda("vietnamjin_2015", tokens_v15, num_topics=8, dir="saved_lda_unique_models")
thesis_lda.analyze_train_test_results(lda_v15, train, test)
thesis_lda.analyze_overall_results(lda_v15, tokens_v15, dict_v15, corpus_v15)
thesis_lda.examine_topics_plain(lda_v15, dict_v15, num_topics=8)

lda_v22, dict_v22, corpus_v22, train, test = thesis_lda.run_lda("vietnamjin_2022", tokens_v22, num_topics=8, dir="saved_lda_unique_models")
thesis_lda.analyze_train_test_results(lda_v22, train, test)
thesis_lda.analyze_overall_results(lda_v22, tokens_v22, dict_v22, corpus_v22)
thesis_lda.examine_topics_plain(lda_v22, dict_v22, num_topics=8)

# %%
# philippinejin
lda_p15, dict_p15, corpus_p15, train, test = thesis_lda.run_lda("philippinejin_2015", tokens_p15, num_topics=8, dir="saved_lda_unique_models")
thesis_lda.analyze_train_test_results(lda_p15, train, test)
thesis_lda.analyze_overall_results(lda_p15, tokens_p15, dict_p15, corpus_p15)
thesis_lda.examine_topics_plain(lda_p15, dict_p15, num_topics=8)

lda_p22, dict_p22, corpus_p22, train, test = thesis_lda.run_lda("philippinejin_2022", tokens_p22, num_topics=8, dir="saved_lda_unique_models")
thesis_lda.analyze_train_test_results(lda_p22, train, test)
thesis_lda.analyze_overall_results(lda_p22, tokens_p22, dict_p22, corpus_p22)
thesis_lda.examine_topics_plain(lda_p22, dict_p22, num_topics=8)

# %% [markdown]
# #### Visualize LDA

# %%
thesis_lda.visualize_topics(lda_z15, corpus_z15, dict_z15)

# %%
thesis_lda.visualize_topics(lda_z22, corpus_z22, dict_z22)

# %% [markdown]
# ### Qualitative Analysis

# %%
lda_z15 = gensim.models.ldamodel.LdaModel.load("saved_lda_models/lda_model_zainichi_2015")
lda_z22 = gensim.models.ldamodel.LdaModel.load("saved_lda_models/lda_model_zainichi_2022")
lda_a15 = gensim.models.ldamodel.LdaModel.load("saved_lda_models/lda_model_ainu_2015")
lda_a22 = gensim.models.ldamodel.LdaModel.load("saved_lda_models/lda_model_ainu_2022")
lda_o15 = gensim.models.ldamodel.LdaModel.load("saved_lda_models/lda_model_okinawa_2015")
lda_o22 = gensim.models.ldamodel.LdaModel.load("saved_lda_models/lda_model_okinawa_2022")
lda_rj15 = gensim.models.ldamodel.LdaModel.load("saved_lda_models/lda_model_ryukyujin_2015")
lda_rj22 = gensim.models.ldamodel.LdaModel.load("saved_lda_models/lda_model_ryukyujin_2022")
lda_h15 = gensim.models.ldamodel.LdaModel.load("saved_lda_models/lda_model_haafu_2015")
lda_h22 = gensim.models.ldamodel.LdaModel.load("saved_lda_models/lda_model_haafu_2022")

# %%
lda_v15 = gensim.models.ldamodel.LdaModel.load("saved_lda_models/lda_model_vietnamjin_2015")
lda_v22= gensim.models.ldamodel.LdaModel.load("saved_lda_models/lda_model_vietnamjin_2022")
lda_p15 = gensim.models.ldamodel.LdaModel.load("saved_lda_models/lda_model_philippinejin_2015")
lda_p22 = gensim.models.ldamodel.LdaModel.load("saved_lda_models/lda_model_philippinejin_2022")

# %%
def print_rep_tweets(rep_df):
    rep_df["Text"] = rep_df["Text"].str.join("")
    for i, rep in enumerate(rep_df["Text"]):
        print("Topic ", str(i))
        print(rep,"\n")

# %%
dict_z15 = gensim.corpora.Dictionary.load("saved_lda_models/lda_model_zainichi_2015.id2word")
corpus_z15 = [dict_z15.doc2bow(text) for text in tokens_z15]
sent_df_z15 = thesis_lda.format_topics_sentences(lda_z15, corpus_z15, tweets_z15)
rep_z15 = thesis_lda.get_representative_docs(sent_df_z15)
print_rep_tweets(rep_z15)

# %%
dict_z22 = gensim.corpora.Dictionary.load("saved_lda_models/lda_model_zainichi_2022.id2word")
corpus_z22 = [dict_z22.doc2bow(text) for text in tokens_z22]
sent_df_z22 = thesis_lda.format_topics_sentences(lda_z22, corpus_z22, tweets_z22)
rep_z22 = thesis_lda.get_representative_docs(sent_df_z22)
print_rep_tweets(rep_z22)

# %%
dict = gensim.corpora.Dictionary.load("saved_lda_models/lda_model_ainu_2015.id2word")
corpus = [dict.doc2bow(text) for text in tokens_a15]
sent_df = thesis_lda.format_topics_sentences(lda_a15, corpus, tweets_a15)
rep = thesis_lda.get_representative_docs(sent_df)
print_rep_tweets(rep)

# %%
dict = gensim.corpora.Dictionary.load("saved_lda_models/lda_model_ainu_2022.id2word")
corpus = [dict.doc2bow(text) for text in tokens_a22]
sent_df = thesis_lda.format_topics_sentences(lda_a22, corpus, tweets_a22)
rep = thesis_lda.get_representative_docs(sent_df)
print_rep_tweets(rep)

# %%
dict = gensim.corpora.Dictionary.load("saved_lda_models/lda_model_okinawa_2015.id2word")
corpus = [dict.doc2bow(text) for text in tokens_o15]
sent_df = thesis_lda.format_topics_sentences(lda_o15, corpus, tweets_o15)
rep = thesis_lda.get_representative_docs(sent_df)
print_rep_tweets(rep)

# %%
dict = gensim.corpora.Dictionary.load("saved_lda_models/lda_model_okinawa_2022.id2word")
corpus = [dict.doc2bow(text) for text in tokens_o22]
sent_df = thesis_lda.format_topics_sentences(lda_o22, corpus, tweets_o22)
rep = thesis_lda.get_representative_docs(sent_df)
print_rep_tweets(rep)

# %%
sent_df = thesis_lda.format_topics_sentences(lda_o22, corpus, tweets_o22)

# %%
sent_df.head()

# %%
import pandas as pd
# group top 5 sentences under each topic
def get_representative_docs_3_per(df_topic_sents_keywords):
    sent_topics_sorteddf = pd.DataFrame()
    sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')
    for _, grp in sent_topics_outdf_grpd:
        sent_topics_sorteddf = pd.concat([sent_topics_sorteddf, 
                                                grp.sort_values(['Perc_Contribution'], ascending=[0]).drop_duplicates(subset=0).head(3)], 
                                                axis=0)
    # reset index    
    sent_topics_sorteddf.reset_index(drop=True, inplace=True)
    # format and show
    sent_topics_sorteddf.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]
    sent_topics_sorteddf.head()
    return sent_topics_sorteddf

# %%
dict = gensim.corpora.Dictionary.load("saved_lda_models/lda_model_ryukyujin_2015.id2word")
corpus = [dict.doc2bow(text) for text in tokens_r15]
sent_df = thesis_lda.format_topics_sentences(lda_rj15, corpus, tweets_r15)
# rep = thesis_lda.get_representative_docs(sent_df)
# print_rep_tweets(rep)

rep_3 = get_representative_docs_3_per(sent_df)
print_rep_tweets(rep_3)

# %%
dict = gensim.corpora.Dictionary.load("saved_lda_models/lda_model_ryukyujin_2022.id2word")
corpus = [dict.doc2bow(text) for text in tokens_r22]
sent_df = thesis_lda.format_topics_sentences(lda_rj22, corpus, tweets_r22)
rep = thesis_lda.get_representative_docs(sent_df)
print_rep_tweets(rep)

# %%
dict = gensim.corpora.Dictionary.load("saved_lda_models/lda_model_haafu_2015_2.id2word")
corpus = [dict.doc2bow(text) for text in tokens_h15]
sent_df = thesis_lda.format_topics_sentences(lda_h15, corpus, tweets_h15)
rep = thesis_lda.get_representative_docs(sent_df)
print_rep_tweets(rep)

# %%
dict = gensim.corpora.Dictionary.load("saved_lda_models/lda_model_haafu_2022.id2word")
corpus = [dict.doc2bow(text) for text in tokens_h22]
sent_df = thesis_lda.format_topics_sentences(lda_h22, corpus, tweets_h22)
rep = thesis_lda.get_representative_docs(sent_df)
print_rep_tweets(rep)

# %%
dict = gensim.corpora.Dictionary.load("saved_lda_models/lda_model_vietnamjin_2015.id2word")
corpus = [dict.doc2bow(text) for text in tokens_v15]
sent_df = thesis_lda.format_topics_sentences(lda_v15, corpus, tweets_v15)
rep = thesis_lda.get_representative_docs(sent_df)
print_rep_tweets(rep)

# %%
dict = gensim.corpora.Dictionary.load("saved_lda_models/lda_model_vietnamjin_2022.id2word")
corpus = [dict.doc2bow(text) for text in tokens_v22]
sent_df = thesis_lda.format_topics_sentences(lda_v22, corpus, tweets_v22)
rep = thesis_lda.get_representative_docs(sent_df)
print_rep_tweets(rep)

# %%
dict = gensim.corpora.Dictionary.load("saved_lda_models/lda_model_philippinejin_2015.id2word")
corpus = [dict.doc2bow(text) for text in tokens_p15]
sent_df = thesis_lda.format_topics_sentences(lda_p15, corpus, tweets_p15)
rep = thesis_lda.get_representative_docs(sent_df)
print_rep_tweets(rep)

# %%
dict = gensim.corpora.Dictionary.load("saved_lda_models/lda_model_philippinejin_2022.id2word")
corpus = [dict.doc2bow(text) for text in tokens_p22]
sent_df = thesis_lda.format_topics_sentences(lda_p22, corpus, tweets_p22)
rep = thesis_lda.get_representative_docs(sent_df)
print_rep_tweets(rep)
